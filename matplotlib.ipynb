# %%
from __future__ import division, print_function, unicode_literals

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,10,3,4])

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4], [5,6,7,8])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %% [markdown]
# # Anatomy of a figure

# %% [markdown]
# major tick, minor tick, major tick label, y axis label, figure, minor tick label, axes, line (line plot), x axis label, spines, markers (scatter plot), legend, grid, title
